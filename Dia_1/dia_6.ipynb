# %% [markdown]
# # Dia 1

# %% [markdown]
# Questões de diferentes perspectivas podem surgir como:
#
#
# - A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?
# - Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?
# - Quais são os temas mais emprestados? E os menos?

# %% [markdown]
# ## Importando os dados

# %%
import pandas as pd

# %%
emprestimos_2010_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20101.csv')
emprestimos_2010_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20102.csv')
emprestimos_2011_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20111.csv')
emprestimos_2011_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20112.csv')
emprestimos_2012_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20121.csv')
emprestimos_2012_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20122.csv')
emprestimos_2013_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20131.csv')
emprestimos_2013_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20132.csv')
emprestimos_2014_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20141.csv')
emprestimos_2014_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20142.csv')
emprestimos_2015_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20151.csv')
emprestimos_2015_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20152.csv')
emprestimos_2016_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20161.csv')
emprestimos_2016_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20162.csv')
emprestimos_2017_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20171.csv')
emprestimos_2017_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20172.csv')
emprestimos_2018_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20181.csv')
emprestimos_2018_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20182.csv')
emprestimos_2019_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20191.csv')
emprestimos_2019_2 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20192.csv')
emprestimos_2020_1 = pd.read_csv(r'Datasets\dados_emprestimos\emprestimos-20201.csv')

# %%
emprestimos_2010_1.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 4         709684       L095049                            NaN
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 4  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %% [markdown]
# Juntando todos os dados de empréstimos em uma único Data Frame visto que todas as colunas tem o mesmo rótulo

# %%
df_emprestimos = pd.concat([emprestimos_2010_1, emprestimos_2010_2, emprestimos_2011_1, emprestimos_2011_2, emprestimos_2012_1, emprestimos_2012_2, emprestimos_2013_1, emprestimos_2013_2, emprestimos_2014_1, emprestimos_2014_2, emprestimos_2015_1, emprestimos_2015_2, emprestimos_2016_1, emprestimos_2016_2, emprestimos_2017_1, emprestimos_2017_2, emprestimos_2018_1, emprestimos_2018_2, emprestimos_2019_1, emprestimos_2019_2, emprestimos_2020_1])

# %% [markdown]
# ## Verificando dados duplicados

# %%
df_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
df_emprestimos.drop_duplicates(inplace=True)

# %% [markdown]
# Verificando se ainda existem ocorrência de dados duplicados

# %%
df_emprestimos.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    1
# 2336122        2011033079     2016/11/21 02:01:58.488000000  2016/11/10 17:00:12.989000000  2016/12/02 14:21:49.000000000  2.016023e+09        ALUNO DE GRADUAÇÃO        1
# 2336103        2014085936     2016/11/25 19:25:36.215000000  2016/11/10 16:54:52.447000000  2016/12/13 14:30:52.000000000  2.014047e+09        ALUNO DE GRADUAÇÃO        1
# 2336104        2011027960     2016/11/23 17:27:54.642000000  2016/11/10 16:55:17.956000000  2016/11/28 10:32:38.000000000  2.016083e+09        ALUNO DE GRADUAÇÃO        1
# ...

# %%
df_exemplares = pd.read_parquet('Datasets\\dados_exemplares.parquet', engine='pyarrow')

# %%
df_exemplares.head()
# Out:
#        id_exemplar codigo_barras            colecao  \
# index
# 0                5       L000003  Acervo Circulante
# 1                4       L000002  Acervo Circulante
# 2                3       L000001  Acervo Circulante
# 3                7       L000114  Acervo Circulante
# 5               10       L000041  Acervo Circulante
#
#                            biblioteca status_material  localizacao  \
# index
# 0      Biblioteca Central Zila Mamede         REGULAR          694
# 1      Biblioteca Central Zila Mamede         REGULAR          688
# 2      Biblioteca Central Zila Mamede        ESPECIAL          638
# 3      Biblioteca Central Zila Mamede         REGULAR          616
# 5      Biblioteca Central Zila Mamede        ESPECIAL          657
#
#        registro_sistema
# index
# 0                     1
# 1                     1
# 2                     1
# 3                     5
# 5                    15

# %%
df_emprestimos['data_renovacao'] = pd.to_datetime(df_emprestimos['data_renovacao'])
df_emprestimos['data_emprestimo'] = pd.to_datetime(df_emprestimos['data_emprestimo'])
df_emprestimos['data_devolucao'] = pd.to_datetime(df_emprestimos['data_devolucao'])

# %%
df_emprestimos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2257981 entries, 0 to 26560
# Data columns (total 7 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id_emprestimo         int64
#  1   codigo_barras         object
#  2   data_renovacao        datetime64[ns]
#  3   data_emprestimo       datetime64[ns]
#  4   data_devolucao        datetime64[ns]
#  5   matricula_ou_siape    float64
#  6   tipo_vinculo_usuario  object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(2)
# memory usage: 137.8+ MB

# %%
df_exemplares.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546237 entries, 0 to 568584
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_exemplar       546237 non-null  int64
#  1   codigo_barras     546237 non-null  object
#  2   colecao           546237 non-null  object
#  3   biblioteca        546237 non-null  object
#  4   status_material   546237 non-null  object
#  5   localizacao       546237 non-null  int64
#  6   registro_sistema  546237 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 33.3+ MB

# %% [markdown]
# ## Mesclando os data frames

# %%
df_merged = pd.merge(df_emprestimos, df_exemplares, how='inner', on='codigo_barras')

# %%
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800        2.008112e+09
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692        2.007211e+08
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662        2.009046e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
df_merged.tail()
# Out:
#          id_emprestimo codigo_barras data_renovacao         data_emprestimo  \
# 2072517        2989086    2008047044            NaT 2020-05-05 19:51:06.059
# 2072518        2989087    2008047047            NaT 2020-05-05 19:51:06.135
# 2072519        2989088    2010052905            NaT 2020-05-05 19:51:06.164
# 2072520        2989089    2010048023            NaT 2020-06-09 11:54:02.669
# 2072521        2989090    2013106838            NaT 2020-06-09 11:54:02.852
#
#              data_devolucao  matricula_ou_siape  \
# 2072517 2021-05-13 14:53:31        3.067431e+06
# 2072518 2021-05-13 14:53:38        3.067431e+06
# 2072519 2021-05-13 15:01:46        3.067431e+06
# 2072520 2021-07-21 15:33:55        2.020101e+10
# 2072521 2021-07-21 15:33:45        2.020101e+10
#
#                     tipo_vinculo_usuario  id_exemplar            colecao  \
# 2072517  SERVIDOR TÉCNICO-ADMINISTRATIVO       256297  Acervo Circulante
# ...

# %% [markdown]
# Através da vizualização das últimas linhas do df podemos perceber que  a última data de emprestimo do ano de 2020 foi no mês 06. Logo não podemos levar os dados de 2020 tanto em consideração pois eles se encontram incompletos com relação ao outros anos

# %% [markdown]
# ### **Em quais bibliotecas do sistema estão a maior quantidade de empréstimos?**

# %%
df_merged['biblioteca'].value_counts()
# Out:
# biblioteca
# Biblioteca Central Zila Mamede                                                              1426122
# Biblioteca Setorial do Centro Ciências da Saúde - CCS                                        118614
# Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz         77609
# Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia               66447
# Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - ­CERES­ - Caicó                     61478
# Biblioteca Setorial Bertha Cruz Enders - ­Escola de Saúde da UFRN - ESUFRN                    46040
# Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA                     40744
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó                                       32097
# Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos                   29089
# ...

# %% [markdown]
# ### **A quantidade de empréstimos está aumentando ou diminuindo ao decorrer dos últimos anos?**

# %%
# Cria uma nova coluna chamada ano extraindo apenas o ano da data de emprestimo
df_merged['ano'] = df_merged['data_emprestimo'].dt.year

# %%
# Conta a quantidade de id_emprestimo por ano
df_emprestimos_por_ano = df_merged.groupby('ano')['id_emprestimo'].count().to_frame()

# %%
df_emprestimos_por_ano.rename(columns={'id_emprestimo':'total_emprestimos'})
# Out:
#       total_emprestimos
# ano
# 2010             161394
# 2011             196390
# 2012             221365
# 2013             234749
# 2014             219189
# 2015             213582
# 2016             215900
# 2017             218462
# 2018             194080
# 2019             171801
# 2020              25610

# %%
import matplotlib.pyplot as plt
import numpy as np

anos = df_emprestimos_por_ano.index
qtd_emprestimos_por_ano = df_emprestimos_por_ano['id_emprestimo']

fig, ax = plt.subplots(figsize=(10,8))
ax.plot(anos, qtd_emprestimos_por_ano)
ax.set_title('Quantidade de empréstimos de livros de 2010 a 2020', fontsize=20)
ax.set_xlabel('anos', fontsize=16)
ax.set_ylabel('Empréstimos', fontsize=16)

plt.yticks(np.arange(20000, 240000, 20000))
plt.grid(True)

# %% [markdown]
# Através dos dados acima podemos perceber que houve um aumento na quantidade de empréstimos de 2010 a 2013, depois teve uma oscilação entre 2014 e 2017 e por fim uma queda de 2017 a 2020.
#
# **Lembrando que os dados de 2020 estão incompletos, logo devem ser desconsiderados**

# %% [markdown]
# ### **Quais são os tipos de usuários que mais utilizam os livros das bibliotecas?**

# %%
df_merged['tipo_vinculo_usuario'].value_counts()
# Out:
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                 1612324
# ALUNO DE PÓS-GRADUAÇÃO              302541
# DOCENTE                              70981
# SERVIDOR TÉCNICO-ADMINISTRATIVO      32184
# ALUNO MÉDIO/TÉCNICO                  28029
# DOCENTE EXTERNO                      23949
# USUÁRIO EXTERNO                       2509
# OUTROS                                   5
# Name: count, dtype: int64

# %% [markdown]
# # Dia 2

# %%
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800        2.008112e+09
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692        2.007211e+08
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662        2.009046e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %% [markdown]
# ### Criar uma nova coluna com os valores da localização, para refletir a respectiva classe geral na CDU

# %%
def classificar_localizacao(x):
    if 0 <= x <= 99:
        return 'Generalidades. Ciência e conhecimento'
    elif 100 <= x <= 199:
        return 'Filosofia e psicologia'
    elif 200 <= x <= 299:
        return 'Religião'
    elif 300 <= x <= 399:
        return 'Ciências sociais'
    elif 400 <= x <= 499:
        return 'Classe vaga. Provisoriamente não ocupada.'
    elif 500 <= x <= 599:
        return 'Matemática e ciências naturais.'
    elif 600 <= x <= 699:
        return 'Ciências aplicadas.'
    elif 700 <= x <= 799:
        return 'Belas artes'
    elif 800 <= x <= 899:
        return 'Linguagem. Língua. Linguística.'
    else:
        return 'Geografia. Biografia. História.'

df_merged['classe_geral'] = df_merged['localizacao'].apply(classificar_localizacao)

# %%
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800        2.008112e+09
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692        2.007211e+08
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662        2.009046e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %% [markdown]
# ### Remover a coluna 'registro_sistema' pois ela não faz sentido para a análise

# %%
df_merged.drop(columns=['registro_sistema'], inplace=True)
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao  matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662        2.008023e+09
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934        2.008023e+09
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800        2.008112e+09
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692        2.007211e+08
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662        2.009046e+09
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
df_merged['matricula_ou_siape'].isna().value_counts()
# Out:
# matricula_ou_siape
# False    2069629
# True        2893
# Name: count, dtype: int64

# %% [markdown]
# ### Alterar o formato da coluna 'matricula_ou_siape' para string para melhorar a legibilidade

# %%
# realiza o cast de tipo dos dados em que o valor da coluna matricula_ou_siape não são nulos
# Faz primeiro a conversão para inteiro, eliminando as casas decimais e depois para str
df_merged['matricula_ou_siape'] = df_merged['matricula_ou_siape'].apply(lambda x: str(int(x)) if pd.notnull(x) else x)

# %%
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800         2008112114
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692          200721119
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662         2009045971
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %% [markdown]
# # Dia 3

# %% [markdown]
# ### Quantidade total de exemplares emprestados por cada ano

# %%
df_merged['id_emprestimo'].value_counts()
# Out:
# id_emprestimo
# 2772079     3
# 2010326     3
# 2014596     3
# 10240112    3
# 2595954     3
#            ..
# 1523986     1
# 1523984     1
# 1523983     1
# 1523981     1
# 2989090     1
# Name: count, Length: 2068724, dtype: int64

# %% [markdown]
# Um mesmo id de emprestimo pode ter mais de um exemplar emprestado

# %%
df_merged.loc[df_merged['id_emprestimo']==2772079]
# Out:
#          id_emprestimo codigo_barras          data_renovacao  \
# 1864848        2772079    2010082016 2018-12-03 16:05:57.708
# 1864849        2772079    2010082016 2018-12-03 16:05:57.708
# 1864850        2772079    2010082016 2018-12-03 16:05:57.708
#
#                 data_emprestimo      data_devolucao matricula_ou_siape  \
# 1864848 2018-11-22 18:28:01.619 2018-12-11 17:54:14        20182022833
# 1864849 2018-11-22 18:28:01.619 2018-12-11 17:54:14        20182022833
# 1864850 2018-11-22 18:28:01.619 2018-12-11 17:54:14        20182022833
#
#            tipo_vinculo_usuario  id_exemplar            colecao  \
# 1864848  ALUNO DE PÓS-GRADUAÇÃO      1055570  Acervo Circulante
# 1864849  ALUNO DE PÓS-GRADUAÇÃO      1055922  Acervo Circulante
# 1864850  ALUNO DE PÓS-GRADUAÇÃO      1056360  Acervo Circulante
#
#                              biblioteca status_material  localizacao   ano  \
# 1864848  Biblioteca Central Zila Mamede         REGULAR          670  2018
# ...

# %% [markdown]
# Quantidade de empréstimos realizados

# %%
qtd_emprestimos = len(df_merged['id_emprestimo'].drop_duplicates())
qtd_emprestimos
# Out:
# 2068724

# %% [markdown]
# Quantidade de exemplares emprestados

# %%
exemplares = len(df_merged)
exemplares
# Out:
# 2072522

# %%
df_emprestimos_datas = pd.DataFrame(df_merged.groupby(['ano'])['data_emprestimo'].value_counts()).reset_index()
df_emprestimos_datas
# Out:
#           ano         data_emprestimo  count
# 0        2010 2010-01-12 14:47:19.758      2
# 1        2010 2010-01-13 12:47:25.563      2
# 2        2010 2010-01-13 16:37:54.455      2
# 3        2010 2010-01-21 10:59:58.256      2
# 4        2010 2010-02-09 15:43:11.210      2
# ...       ...                     ...    ...
# 2068686  2020 2020-05-05 19:51:06.059      1
# 2068687  2020 2020-05-05 19:51:06.135      1
# 2068688  2020 2020-05-05 19:51:06.164      1
# 2068689  2020 2020-06-09 11:54:02.669      1
# 2068690  2020 2020-06-09 11:54:02.852      1
#
# [2068691 rows x 3 columns]

# %%
df_emprestimos_datas.drop(columns='data_emprestimo', inplace=True)
df_emprestimos_datas = df_emprestimos_datas.set_index('ano')
df_emprestimos_datas
# Out:
#       count
# ano
# 2010      2
# 2010      2
# 2010      2
# 2010      2
# 2010      2
# ...     ...
# 2020      1
# 2020      1
# 2020      1
# 2020      1
# 2020      1
#
# [2068691 rows x 1 columns]

# %%
df_exemplares_por_ano = df_emprestimos_datas.groupby('ano').sum()
df_exemplares_por_ano
# Out:
#        count
# ano
# 2010  161394
# 2011  196390
# 2012  221365
# 2013  234749
# 2014  219189
# 2015  213582
# 2016  215900
# 2017  218462
# 2018  194080
# 2019  171801
# 2020   25610

# %%
anos = df_emprestimos_por_ano.index

fig, ax = plt.subplots(figsize=(10,8))
ax.plot(anos, df_exemplares_por_ano['count'])
ax.set_title('Quantidade de exemplares emprestados de 2010 a 2020', fontsize=20)
ax.set_xlabel('anos', fontsize=16)
ax.set_ylabel('Empréstimos', fontsize=16)

plt.grid(True)

# %% [markdown]
# Devido ao pequeno número de id_emprestimos com mais de um exemplar emprestado. O gráfico é bastante parecido com o gráfico de empréstimos por ano

# %% [markdown]
# ### A diretoria também gostaria de gerenciar melhor os recursos humanos da biblioteca de acordo com a demanda de trabalho existente. Por exemplo:
#
#
# - gerenciar a programação de férias dos colaboradores de acordo com os meses de menor demanda
#
# - programar atividades que não sejam de atendimento ao usuário para períodos específicos de menor demanda.

# %% [markdown]
#  ### Gere uma tabela com a quantidade total de exemplares emprestados por mês e descubra quais meses são os que possuem a maior quantidade de empréstimos realizados. Plote um gráfico de linhas.

# %%
df_merged['mes'] = df_merged['data_emprestimo'].dt.month
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800         2008112114
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692          200721119
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662         2009045971
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
df_emprestimos_por_mes = df_merged.groupby('mes')['id_emprestimo'].count().to_frame()
df_emprestimos_por_mes
# Out:
#      id_emprestimo
# mes
# 1            67514
# 2           210200
# 3           252185
# 4           208725
# 5           202530
# 6           138123
# 7           123790
# 8           232793
# 9           208234
# 10          188410
# 11          164222
# 12           75796

# %%
meses = {
    1: 'Janeiro', 2: 'Fevereiro', 3: 'Março', 4: 'Abril',
    5: 'Maio', 6: 'Junho', 7: 'Julho', 8: 'Agosto',
    9: 'Setembro', 10: 'Outubro', 11: 'Novembro', 12: 'Dezembro'
}

df_emprestimos_por_mes.index = df_emprestimos_por_mes.index.map(meses)
df_emprestimos_por_mes.rename(columns={'id_emprestimo':'total'}, inplace=True)
df_emprestimos_por_mes
# Out:
#             total
# mes
# Janeiro     67514
# Fevereiro  210200
# Março      252185
# Abril      208725
# Maio       202530
# Junho      138123
# Julho      123790
# Agosto     232793
# Setembro   208234
# Outubro    188410
# Novembro   164222
# Dezembro    75796

# %%
meses = df_emprestimos_por_mes.index

fig, ax = plt.subplots(figsize=(14,8))
ax.plot(meses, df_emprestimos_por_mes['total'])
ax.set_title('Quantidade de exemplares emprestados por mês', fontsize=20)
ax.set_xlabel('Meses', fontsize=16)
ax.set_ylabel('Empréstimos', fontsize=16)

plt.grid(True)

# %% [markdown]
# Visto que a maior parte do público das bibliotecas são estudantes principalmente de graduação e pós-graduação, afim de um melhor gerenciamento do RH da biblioteca o atendimento ao público tem uma menor demanda nos meses de férias como janeiro, julho e dezembro, como podemos observar no gráfico acima. Logo esses meses são os ideais para programar as férias de seus colaboradores que participam ativamente de atividades de atendimento ao público.

# %% [markdown]
# ### Verificar quais foram os horários com maior quantidade de empréstimos ao longo de um dia inteiro.

# %%
df_merged['hora_emprestimo'] = df_merged['data_emprestimo'].dt.hour
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800         2008112114
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692          200721119
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662         2009045971
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
df_emprestimos_por_hora = df_merged['hora_emprestimo'].value_counts().sort_index().to_frame()
df_emprestimos_por_hora = df_emprestimos_por_hora.reset_index()
df_emprestimos_por_hora
# Out:
#     hora_emprestimo   count
# 0                 0      17
# 1                 6      14
# 2                 7   18777
# 3                 8  103416
# 4                 9  131273
# 5                10  185839
# 6                11  180048
# 7                12  148754
# 8                13  126987
# 9                14  150876
# 10               15  166672
# 11               16  210655
# 12               17  185340
# 13               18  182520
# 14               19  102129
# 15               20  127716
# 16               21   51191
# 17               22     247
# 18               23      51

# %%
import matplotlib.pyplot as plt
import numpy as np

horas = df_emprestimos_por_hora['hora_emprestimo']
total = df_emprestimos_por_hora['count']

# Normalizando (%) os valores de 'count' para definir as cores
norm = plt.Normalize(df_emprestimos_por_hora['count'].min(), df_emprestimos_por_hora['count'].max())
colors = plt.cm.Blues(norm(df_emprestimos_por_hora['count']))

# Definindo as posições das barras com espaçamento extra
x_positions = np.arange(len(horas)) * 1.2  # Multiplica por 1.2 para adicionar espaço entre as barras

# Criando o gráfico de barras com espaçamento
plt.bar(x_positions, total, color=colors, width=0.8)  # A largura pode ser ajustada conforme necessário

# Ajustando os xticks para corresponder às novas posições com os rótulos formatados
plt.xticks(ticks=x_positions, labels=[f'{h}' for h in horas])

# Adicionando título e rótulos aos eixos
plt.title('Total de Empréstimos por Hora')
plt.xlabel('Hora do Empréstimo')
plt.ylabel('Total de Empréstimos')

plt.tight_layout()  # Ajusta automaticamente o layout para evitar sobreposição
plt.show()

# %% [markdown]
# Através do gráfico podemos observar que os horários de maior pico são 10h e 16h. Nós horários de início da manhã as 7h e início da noite as 19h são os melhores horários para se fazer atividades além do atendimento ao público por serem os horários com menor movimento.

# %% [markdown]
# # Dia 4

# %%
df_merged.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800         2008112114
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692          200721119
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662         2009045971
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
df_merged['tipo_vinculo_usuario'].value_counts()
# Out:
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                 1612324
# ALUNO DE PÓS-GRADUAÇÃO              302541
# DOCENTE                              70981
# SERVIDOR TÉCNICO-ADMINISTRATIVO      32184
# ALUNO MÉDIO/TÉCNICO                  28029
# DOCENTE EXTERNO                      23949
# USUÁRIO EXTERNO                       2509
# OUTROS                                   5
# Name: count, dtype: int64

# %%
df_merged['colecao'].value_counts()
# Out:
# colecao
# Acervo Circulante                        2053120
# Multimeios                                  7954
# Monografias                                 4021
# Dissertações                                2406
# Obras de Referência                         1954
# Publicações de Autores do RN                 866
# Publicações da UFRN                          764
# Teses                                        714
# Folhetos                                     271
# Necessidades Educacionais Específicas        130
# Trabalho Acadêmico                           115
# Eventos                                      101
# Coleção Mossoroense                           44
# Coleção Zila Mamede                           30
# Literatura de Cordel                          24
# Obras Raras                                    8
# Name: count, dtype: int64

# %%
df_merged['biblioteca'].value_counts()
# Out:
# biblioteca
# Biblioteca Central Zila Mamede                                                              1426122
# Biblioteca Setorial do Centro Ciências da Saúde - CCS                                        118614
# Biblioteca Setorial da Faculdade de Ciências da Saúde do Trairi - FACISA - Santa Cruz         77609
# Biblioteca Setorial Prof. Alberto Moreira Campos - ­Departamento de Odontologia               66447
# Biblioteca Setorial Profª. Maria Lúcia da Costa Bezerra - ­CERES­ - Caicó                     61478
# Biblioteca Setorial Bertha Cruz Enders - ­Escola de Saúde da UFRN - ESUFRN                    46040
# Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA                     40744
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN - Caicó                                       32097
# Biblioteca Setorial Profª. Maria José Mamede Galvão - FELCS - Currais Novos                   29089
# ...

# %%
df_merged['classe_geral'].value_counts()
# Out:
# classe_geral
# Ciências aplicadas.                      1425473
# Ciências sociais                          369536
# Matemática e ciências naturais.            68744
# Generalidades. Ciência e conhecimento      62521
# Religião                                   62295
# Filosofia e psicologia                     60563
# Geografia. Biografia. História.             7989
# Belas artes                                 7911
# Linguagem. Língua. Linguística.             7490
# Name: count, dtype: int64

# %%
def quantidade_percentual(variavel):
    df = pd.DataFrame(df_merged[variavel].value_counts())
    df.columns = ['quantidade']
    df['percentual'] = round((df['quantidade'] / df['quantidade'].sum()) *100, 1)

    return df

# %%
quantidade_percentual('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324        77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541        14.6
# DOCENTE                               70981         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184         1.6
# ALUNO MÉDIO/TÉCNICO                   28029         1.4
# DOCENTE EXTERNO                       23949         1.2
# USUÁRIO EXTERNO                        2509         0.1
# OUTROS                                    5         0.0

# %%
quantidade_percentual('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         2053120        99.1
# Multimeios                                   7954         0.4
# Monografias                                  4021         0.2
# Dissertações                                 2406         0.1
# Obras de Referência                          1954         0.1
# Publicações de Autores do RN                  866         0.0
# Publicações da UFRN                           764         0.0
# Teses                                         714         0.0
# Folhetos                                      271         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# ...

# %% [markdown]
# De acordo com os dados extraídos podemos ver que 99% da coleção do Acervo circulante já está sob empréstimo. Através disso podemos ir atrás do por quê outros tipos de coleções importantes como monografias e dissertações não são tão procuradas.

# %%
quantidade_percentual('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1426122        68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923         1.3
# ...

# %%
quantidade_percentual('classe_geral')
# Out:
#                                        quantidade  percentual
# classe_geral
# Ciências aplicadas.                       1425473        68.8
# Ciências sociais                           369536        17.8
# Matemática e ciências naturais.             68744         3.3
# Generalidades. Ciência e conhecimento       62521         3.0
# Religião                                    62295         3.0
# Filosofia e psicologia                      60563         2.9
# Geografia. Biografia. História.              7989         0.4
# Belas artes                                  7911         0.4
# Linguagem. Língua. Linguística.              7490         0.4

# %% [markdown]
# Através desses dados podemos procurar entender por que temas como  Geografia/Biografia/História, Belas artes e Linguagem estão com números tão baixos.

# %% [markdown]
# # Dia 5

# %%
df_merged.head(3)
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 2         709686    2006017618 2010-01-26 08:07:01.738
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800         2008112114
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# 1                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
#  Avaliar dentre os alunos de graduação e pós graduação a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 da coleção que tiver a maior frequência de empréstimos.

# %%
# Verifica qual a coleção mais utilizada pelos alunos de pós graduação
df_merged[df_merged['tipo_vinculo_usuario'] == "ALUNO DE PÓS-GRADUAÇÃO"]['colecao'].value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %%
# Verifica qual a coleção mais utilizada pelos alunos de graduação
df_merged[df_merged['tipo_vinculo_usuario'] == "ALUNO DE GRADUAÇÃO"]['colecao'].value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
# Criando um df apenas com os empréstimos realizados pelos alunos de graduação
df_graduacao = df_merged[df_merged['tipo_vinculo_usuario'] == "ALUNO DE GRADUAÇÃO"]

# Filtra apenas os empréstimos da coleção acervo circulante, já que é a coleção mais utilizado
df_graduacao = df_graduacao[df_graduacao['colecao'] == 'Acervo Circulante']

# Agrupa por ano e retorna a quantidade de empréstimos realizados em cada mês
df_graduacao = pd.DataFrame(df_graduacao.groupby('ano')['mes'].value_counts()).reset_index()
df_graduacao.set_index('ano', inplace=True)
df_graduacao
# Out:
#       mes  count
# ano
# 2010    3  15275
# 2010    9  14763
# 2010    8  14672
# 2010    4  12430
# 2010   10  12283
# ...   ...    ...
# 2019    1   2276
# 2019   12   1980
# 2020    3   8685
# 2020    2   8138
# 2020    1   1781
#
# [123 rows x 2 columns]

# %%
# Realizando a mesma filtragem para os alunos de pós graduação
df_pos = df_merged[df_merged['tipo_vinculo_usuario'] == "ALUNO DE PÓS-GRADUAÇÃO"]
df_pos = df_pos[df_pos['colecao'] == 'Acervo Circulante']
df_pos = pd.DataFrame(df_pos.groupby('ano')['mes'].value_counts()).reset_index()
df_pos.set_index('ano', inplace=True)
df_pos
# Out:
#       mes  count
# ano
# 2010    3   2919
# 2010    4   2716
# 2010    5   2514
# 2010    9   2297
# 2010    8   2222
# ...   ...    ...
# 2019   12   1069
# 2020    3   1471
# 2020    2   1189
# 2020    1   1143
# 2020    6      2
#
# [124 rows x 2 columns]

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.ticker as ticker


def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(16,10))                                                           

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')                                           
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel(None)                                                                     
  plt.ylabel(None)                                                                    

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(df_graduacao,'ano','count','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %%
gera_box_plot(df_pos,'ano','count','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# # Dia 6

# %% [markdown]
# Calcular a quantidade de empréstimos realizados entre 2015 e 2020 por cada curso de graduação que passará pela avaliação.
#
# Os cursos serão:
# - Biblioteconomia
# - Ciências sociais
# - Comunicação social
# - Direito
# - Filosofia
# - Pedagogia

# %%
matriculas_antes_2010 = pd.read_excel(r'Datasets\matricula_alunos.xlsx', sheet_name='Até 2010', header=1)
matriculas_apos_2010 = pd.read_excel(r'Datasets\matricula_alunos.xlsx', sheet_name='Após 2010', header=1)

# %%
matriculas_antes_2010.head()
# Out:
#    Número da matrícula     Tipo de vinculo                Curso
# 0          190001688.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1          199014489.0  ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2          199735674.0  ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3          199812431.0  ALUNO DE GRADUAÇÃO               LETRAS
# 4          199823670.0  ALUNO DE GRADUAÇÃO             ECOLOGIA

# %%
matriculas_antes_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7726 entries, 0 to 7725
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Número da matrícula  7726 non-null   float64
#  1   Tipo de vinculo      7726 non-null   object
#  2   Curso                7726 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 181.2+ KB

# %%
matriculas_apos_2010.head()
# Out:
#      Matricula      Tipo de vinculo                Cursos
# 0  2.010000e+09  ALUNO DE GRADUAÇÃO               DIREITO
# 1  2.010000e+09  ALUNO DE GRADUAÇÃO             AGRONOMIA
# 2  2.010001e+09  ALUNO DE GRADUAÇÃO    ENGENHARIA QUÍMICA
# 3  2.010003e+09  ALUNO DE GRADUAÇÃO  ENGENHARIA AMBIENTAL
# 4  2.010003e+09  ALUNO DE GRADUAÇÃO             GEOGRAFIA

# %%
matriculas_apos_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2274 entries, 0 to 2273
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Matricula        2274 non-null   float64
#  1   Tipo de vinculo  2274 non-null   object
#  2   Cursos           2274 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 53.4+ KB

# %%
# padroniza as colunas de acordo com o df com os empréstimos
matriculas_antes_2010.columns = ['matricula_ou_siape', 'tipo_vinculo_usuario', 'curso']
matriculas_apos_2010.columns = ['matricula_ou_siape', 'tipo_vinculo_usuario', 'curso']

# %%
# Transforma primeiro em int para eliminar a casa decimal e depois em string que é o padrão utilizado no df de empréstimos
matriculas_antes_2010['matricula_ou_siape'] = matriculas_antes_2010['matricula_ou_siape'].astype('int64')
matriculas_antes_2010['matricula_ou_siape'] = matriculas_antes_2010['matricula_ou_siape'].astype('string')

matriculas_apos_2010['matricula_ou_siape'] = matriculas_apos_2010['matricula_ou_siape'].astype('int64')
matriculas_apos_2010['matricula_ou_siape'] = matriculas_apos_2010['matricula_ou_siape'].astype('string')

# %%
matriculas_antes_2010.head()
# Out:
#   matricula_ou_siape tipo_vinculo_usuario                curso
# 0          190001688   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 1          199014489   ALUNO DE GRADUAÇÃO  CIÊNCIAS BIOLÓGICAS
# 2          199735674   ALUNO DE GRADUAÇÃO           MATEMÁTICA
# 3          199812431   ALUNO DE GRADUAÇÃO               LETRAS
# 4          199823670   ALUNO DE GRADUAÇÃO             ECOLOGIA

# %%
matriculas_apos_2010.head()
# Out:
#   matricula_ou_siape tipo_vinculo_usuario                 curso
# 0         2010000017   ALUNO DE GRADUAÇÃO               DIREITO
# 1         2010000035   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 2         2010001290   ALUNO DE GRADUAÇÃO    ENGENHARIA QUÍMICA
# 3         2010002849   ALUNO DE GRADUAÇÃO  ENGENHARIA AMBIENTAL
# 4         2010003381   ALUNO DE GRADUAÇÃO             GEOGRAFIA

# %%
matriculas_graduacao_excel = pd.concat([matriculas_antes_2010, matriculas_apos_2010], ignore_index=True)
matriculas_graduacao_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0             190001688   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1             199014489   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2             199735674   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3             199812431   ALUNO DE GRADUAÇÃO                    LETRAS
# 4             199823670   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995        20150116770   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996         2015074523   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997        20160002745   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998        20170086533   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999        20180090351   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %%
# Verifica se possui algum dado nulo no df
matriculas_graduacao_excel.isna().sum()
# Out:
# matricula_ou_siape      0
# tipo_vinculo_usuario    0
# curso                   0
# dtype: int64

# %%
matriculas_alunos_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')

matriculas_alunos_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
matriculas_graduacao_json = pd.read_json(matriculas_alunos_json.registros[0])
matriculas_graduacao_json
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_11920\4254198796.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matriculas_graduacao_json = pd.read_json(matriculas_alunos_json.registros[0])
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# ...

# %%
matriculas_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
# Converte os dados para o padrão utilizado nos outros DataFrames
matriculas_graduacao_json['matricula_ou_siape'] = matriculas_graduacao_json['matricula_ou_siape'].astype('string')

# %%
# concatena os dois DataFrames
matriculas_graduacao = pd.concat([matriculas_graduacao_excel, matriculas_graduacao_json], ignore_index=True)
matriculas_graduacao
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0              190001688   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1              199014489   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2              199735674   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3              199812431   ALUNO DE GRADUAÇÃO                LETRAS
# 4              199823670   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797        20200012706   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798        20200039601   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799        20200132517   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800        20200009344   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801        20200090284   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %%
matriculas_pos = pd.read_json(matriculas_alunos_json.registros[1])
matriculas_pos
# Out:
# C:\Users\Felipe\AppData\Local\Temp\ipykernel_11920\4167424325.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matriculas_pos = pd.read_json(matriculas_alunos_json.registros[1])
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2008112114  ALUNO DE PÓS-GRADUAÇÃO
# 1              2008106583  ALUNO DE PÓS-GRADUAÇÃO
# 2              2011101417  ALUNO DE PÓS-GRADUAÇÃO
# 3              2011113122  ALUNO DE PÓS-GRADUAÇÃO
# 4              2010110903  ALUNO DE PÓS-GRADUAÇÃO
# ...                   ...                     ...
# 19435         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 19436         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 19437         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 19438         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 19439         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# ...

# %%
# pegando do df principal apenas os alunos de graduação
df_graduacao_filtrado = df_merged.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
df_graduacao_filtrado.head()
# Out:
#    id_emprestimo codigo_barras          data_renovacao  \
# 0         709684       L095049                     NaT
# 1         709685       L167050                     NaT
# 3         709687       L184117 2010-01-18 11:07:46.470
# 4         709688    2007027500 2010-01-19 15:59:26.464
# 5         709689       L157395 2010-01-19 15:59:26.447
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662         2008023265
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934         2008023265
# 3 2010-01-04 08:24:21.284 2010-02-03 08:58:45.692          200721119
# 4 2010-01-04 08:27:33.569 2010-02-03 13:06:30.662         2009045971
# 5 2010-01-04 08:27:33.596 2010-02-03 13:06:43.125         2009045971
#
#   tipo_vinculo_usuario  id_exemplar            colecao  \
# 0   ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1   ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# ...

# %%
# pega todas as linhas das colunas selecionadas
df_graduacao_filtrado = df_graduacao_filtrado.loc[:,['matricula_ou_siape', 'data_emprestimo']]
df_graduacao_filtrado
# Out:
#         matricula_ou_siape         data_emprestimo
# 0               2008023265 2010-01-04 07:44:10.721
# 1               2008023265 2010-01-04 07:44:10.750
# 3                200721119 2010-01-04 08:24:21.284
# 4               2009045971 2010-01-04 08:27:33.569
# 5               2009045971 2010-01-04 08:27:33.596
# ...                    ...                     ...
# 2072500        20190154579 2020-03-18 16:26:20.477
# 2072501        20160129109 2020-03-18 16:41:28.500
# 2072502        20160129109 2020-03-18 16:41:28.588
# 2072503        20160129109 2020-03-18 16:41:28.662
# 2072504        20160129109 2020-03-18 16:41:28.713
#
# [1612324 rows x 2 columns]

# %%
# filtrando apenas os emprestimos realizados a partir de 2015 e reseta os indices
df_graduacao_filtrado = df_graduacao_filtrado.query('data_emprestimo > 2015')
df_graduacao_filtrado = df_graduacao_filtrado.reset_index(drop=True)
df_graduacao_filtrado
# Out:
#        matricula_ou_siape         data_emprestimo
# 0              2013021576 2015-01-02 09:16:49.566
# 1              2014026648 2015-01-02 09:44:42.808
# 2              2014026648 2015-01-02 09:44:43.127
# 3              2010049586 2015-01-02 10:11:09.837
# 4              2014021454 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 788099        20190154579 2020-03-18 16:26:20.477
# 788100        20160129109 2020-03-18 16:41:28.500
# 788101        20160129109 2020-03-18 16:41:28.588
# 788102        20160129109 2020-03-18 16:41:28.662
# 788103        20160129109 2020-03-18 16:41:28.713
#
# [788104 rows x 2 columns]

# %% [markdown]
# Como queremos filtrar por cursos, mas nem todo usuário da biblioteca está inserido em algum curso como aluno, é preciso verificar se existe alguma matrícula com valor nulo

# %%
df_graduacao_filtrado['matricula_ou_siape'].isna().sum()
# Out:
# 94

# %%
df_graduacao_filtrado.dropna(inplace=True)

# %%
df_graduacao_filtrado['matricula_ou_siape'].isna().sum()
# Out:
# 0

# %% [markdown]
# Após a limpeza vamos filtrar os cursos que foram selecionados

# %%
matriculas_cursos_selecionados = matriculas_graduacao.query('curso == curso == ["BIBLIOTECONOMIA","CIÊNCIAS SOCIAIS","COMUNICAÇÃO SOCIAL","DIREITO","FILOSOFIA","PEDAGOGIA"]')

matriculas_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario             curso
# 8              200031011   ALUNO DE GRADUAÇÃO           DIREITO
# 9              200045080   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15             200115053   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18             200123382   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19             200123730   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                  ...                  ...               ...
# 72789        20200097481   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796        20200107087   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797        20200012706   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800        20200009344   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801        20200090284   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %%
emprestimos_cursos_selecionados = df_graduacao_filtrado.merge(matriculas_cursos_selecionados)
emprestimos_cursos_selecionados
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0              2014021454 2015-01-02 10:19:38.087   ALUNO DE GRADUAÇÃO
# 1              2013018187 2015-01-02 10:25:40.883   ALUNO DE GRADUAÇÃO
# 2              2014029499 2015-01-02 12:26:43.571   ALUNO DE GRADUAÇÃO
# 3              2014029499 2015-01-02 12:26:43.840   ALUNO DE GRADUAÇÃO
# 4              2014029499 2015-01-02 12:26:44.750   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 213735        20200090284 2020-03-17 20:23:54.966   ALUNO DE GRADUAÇÃO
# 213736        20180113385 2020-03-17 21:20:47.278   ALUNO DE GRADUAÇÃO
# 213737        20190150079 2020-03-18 13:43:53.220   ALUNO DE GRADUAÇÃO
# 213738        20190150079 2020-03-18 13:43:53.389   ALUNO DE GRADUAÇÃO
# 213739        20190150079 2020-03-18 13:43:53.456   ALUNO DE GRADUAÇÃO
#
#                    curso
# 0              FILOSOFIA
# 1                DIREITO
# 2       CIÊNCIAS SOCIAIS
# ...

# %% [markdown]
# Gere uma tabela com as seguintes características:
#
# - Índice: Cursos
# - Colunas: Ano
# - Valores: Quantidade de empréstimos
# - Total: Acrescente uma linha e uma coluna de total a tabela

# %%
emprestimos_cursos_selecionados['data_emprestimo'] = emprestimos_cursos_selecionados['data_emprestimo'].dt.year
emprestimos_cursos_selecionados.head()
# Out:
#   matricula_ou_siape  data_emprestimo tipo_vinculo_usuario             curso
# 0         2014021454             2015   ALUNO DE GRADUAÇÃO         FILOSOFIA
# 1         2013018187             2015   ALUNO DE GRADUAÇÃO           DIREITO
# 2         2014029499             2015   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 3         2014029499             2015   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 4         2014029499             2015   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS

# %%
emprestimos_por_curso = emprestimos_cursos_selecionados.groupby('data_emprestimo')['curso'].value_counts().to_frame().reset_index()
emprestimos_por_curso.head()
# Out:
#    data_emprestimo               curso  count
# 0             2015     BIBLIOTECONOMIA   7814
# 1             2015             DIREITO   7719
# 2             2015    CIÊNCIAS SOCIAIS   7531
# 3             2015           PEDAGOGIA   7209
# 4             2015  COMUNICAÇÃO SOCIAL   7165

# %%
emprestimos_por_curso.columns = ['ano', 'curso', 'qtd_emprestimos']
emprestimos_por_curso.sort_values('qtd_emprestimos', ascending=False, inplace=True)
emprestimos_por_curso.reset_index(drop=True, inplace=True)
emprestimos_por_curso.head()
# Out:
#     ano               curso  qtd_emprestimos
# 0  2017  COMUNICAÇÃO SOCIAL             8281
# 1  2016  COMUNICAÇÃO SOCIAL             7997
# 2  2017             DIREITO             7923
# 3  2015     BIBLIOTECONOMIA             7814
# 4  2015             DIREITO             7719

# %%
emprestimos_por_curso_pivot = emprestimos_por_curso.pivot_table(index='curso', columns='ano', values='qtd_emprestimos', aggfunc='sum', margins=True, margins_name='total')

emprestimos_por_curso_pivot
# Out:
# ano                  2015   2016   2017   2018   2019  2020   total
# curso
# BIBLIOTECONOMIA      7814   7066   7325   6400   5935   906   35446
# CIÊNCIAS SOCIAIS     7531   7012   6950   6209   5814   827   34343
# COMUNICAÇÃO SOCIAL   7165   7997   8281   6989   5923   800   37155
# DIREITO              7719   7397   7923   7073   5895   907   36914
# FILOSOFIA            6984   7586   7417   6314   5602   832   34735
# PEDAGOGIA            7209   7181   7462   6534   5891   870   35147
# total               44422  44239  45358  39519  35060  5142  213740
